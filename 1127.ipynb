# %%
import pandas as pd

# %%
score1 = pd.read_csv('중간기말성적.csv', encoding = 'EUC_KR')
score1.head()
# Out:
#      학번 분반 성별  중간고사  기말고사
# 0  2201  B  여    82    79
# 1  2202  A  여    82    91
# 2  2203  A  여    93    27
# 3  2204  B  여    79    81
# 4  2205  B  여    90    88

# %%
score1[score1['분반'] == 'A']
# Out:
#       학번 분반 성별  중간고사  기말고사
# 1   2202  A  여    82    91
# 2   2203  A  여    93    27
# 6   2207  A  여    85    79
# 7   2208  A  여    91    96
# 12  2213  A  남    58    50
# 13  2214  A  남    76    93
# 14  2215  A  남    89    79
# 15  2216  A  남    32    57
# 19  2220  A  남    80    85
# 20  2221  A  남    91    98

# %%
score1[score1['성별'] == '여']
# Out:
#      학번 분반 성별  중간고사  기말고사
# 0  2201  B  여    82    79
# 1  2202  A  여    82    91
# 2  2203  A  여    93    27
# 3  2204  B  여    79    81
# 4  2205  B  여    90    88
# 5  2206  B  여    84    82
# 6  2207  A  여    85    79
# 7  2208  A  여    91    96
# 8  2209  B  여   100    98
# 9  2210  B  여    72    70

# %%
score1[score1['성별'] != '여'].head()
# Out:
#       학번 분반 성별  중간고사  기말고사
# 10  2211  B  남    88    85
# 11  2212  B  남    85    82
# 12  2213  A  남    58    50
# 13  2214  A  남    76    93
# 14  2215  A  남    89    79

# %%
score1[score1['중간고사'] >= 90]
# Out:
#       학번 분반 성별  중간고사  기말고사
# 2   2203  A  여    93    27
# 4   2205  B  여    90    88
# 7   2208  A  여    91    96
# 8   2209  B  여   100    98
# 20  2221  A  남    91    98

# %%
score1[(score1['중간고사'] >= 90) & (score1['기말고사'] >= 90)]
# Out:
#       학번 분반 성별  중간고사  기말고사
# 7   2208  A  여    91    96
# 8   2209  B  여   100    98
# 20  2221  A  남    91    98

# %%
score1[(score1['중간고사'] >= 90) | (score1['기말고사'] >= 90)]
# Out:
#       학번 분반 성별  중간고사  기말고사
# 1   2202  A  여    82    91
# 2   2203  A  여    93    27
# 4   2205  B  여    90    88
# 7   2208  A  여    91    96
# 8   2209  B  여   100    98
# 13  2214  A  남    76    93
# 16  2217  B  남    82    95
# 17  2218  B  남    85   100
# 20  2221  A  남    91    98

# %%
score1.query('분반 == "A"')
# Out:
#       학번 분반 성별  중간고사  기말고사
# 1   2202  A  여    82    91
# 2   2203  A  여    93    27
# 6   2207  A  여    85    79
# 7   2208  A  여    91    96
# 12  2213  A  남    58    50
# 13  2214  A  남    76    93
# 14  2215  A  남    89    79
# 15  2216  A  남    32    57
# 19  2220  A  남    80    85
# 20  2221  A  남    91    98

# %%
여학생 = score1.query('성별 == "여"')
여학생
# Out:
#      학번 분반 성별  중간고사  기말고사
# 0  2201  B  여    82    79
# 1  2202  A  여    82    91
# 2  2203  A  여    93    27
# 3  2204  B  여    79    81
# 4  2205  B  여    90    88
# 5  2206  B  여    84    82
# 6  2207  A  여    85    79
# 7  2208  A  여    91    96
# 8  2209  B  여   100    98
# 9  2210  B  여    72    70

# %%
score1.query('성별 != "여"').head()
# Out:
#       학번 분반 성별  중간고사  기말고사
# 10  2211  B  남    88    85
# 11  2212  B  남    85    82
# 12  2213  A  남    58    50
# 13  2214  A  남    76    93
# 14  2215  A  남    89    79

# %%
score1.query('중간고사 >= 90')
# Out:
#       학번 분반 성별  중간고사  기말고사
# 2   2203  A  여    93    27
# 4   2205  B  여    90    88
# 7   2208  A  여    91    96
# 8   2209  B  여   100    98
# 20  2221  A  남    91    98

# %%
score1.query('중간고사 >= 90 & 기말고사 >= 90')
# Out:
#       학번 분반 성별  중간고사  기말고사
# 7   2208  A  여    91    96
# 8   2209  B  여   100    98
# 20  2221  A  남    91    98

# %%
score1.query('중간고사 >= 90 | 기말고사 >= 90')
# Out:
#       학번 분반 성별  중간고사  기말고사
# 1   2202  A  여    82    91
# 2   2203  A  여    93    27
# 4   2205  B  여    90    88
# 7   2208  A  여    91    96
# 8   2209  B  여   100    98
# 13  2214  A  남    76    93
# 16  2217  B  남    82    95
# 17  2218  B  남    85   100
# 20  2221  A  남    91    98

# %%
score1.query('기말고사 >= 90')['분반']
# Out:
# 1     A
# 7     A
# 8     B
# 13    A
# 16    B
# 17    B
# 20    A
# Name: 분반, dtype: object

# %%
score1.query('기말고사 >= 90')[['분반']]
# Out:
#    분반
# 1   A
# 7   A
# 8   B
# 13  A
# 16  B
# 17  B
# 20  A

# %%
score1.query('기말고사 >= 90')[['분반', '학번']]
# Out:
#    분반    학번
# 1   A  2202
# 7   A  2208
# 8   B  2209
# 13  A  2214
# 16  B  2217
# 17  B  2218
# 20  A  2221

# %%
score1.sort_values('중간고사').head()
# Out:
#       학번 분반 성별  중간고사  기말고사
# 15  2216  A  남    32    57
# 12  2213  A  남    58    50
# 9   2210  B  여    72    70
# 13  2214  A  남    76    93
# 18  2219  B  남    79    89

# %%
score1.sort_values('중간고사', ascending = False).head()
# Out:
#       학번 분반 성별  중간고사  기말고사
# 8   2209  B  여   100    98
# 2   2203  A  여    93    27
# 20  2221  A  남    91    98
# 7   2208  A  여    91    96
# 4   2205  B  여    90    88

# %%
score1.sort_values(['성별', '기말고사'])
# Out:
#       학번 분반 성별  중간고사  기말고사
# 12  2213  A  남    58    50
# 15  2216  A  남    32    57
# 14  2215  A  남    89    79
# 11  2212  B  남    85    82
# 10  2211  B  남    88    85
# 19  2220  A  남    80    85
# 18  2219  B  남    79    89
# 13  2214  A  남    76    93
# 16  2217  B  남    82    95
# 20  2221  A  남    91    98
# 17  2218  B  남    85   100
# 2   2203  A  여    93    27
# 9   2210  B  여    72    70
# 0   2201  B  여    82    79
# 6   2207  A  여    85    79
# 3   2204  B  여    79    81
# 5   2206  B  여    84    82
# 4   2205  B  여    90    88
# 1   2202  A  여    82    91
# 7   2208  A  여    91    96
# 8   2209  B  여   100    98

# %%
score1.sort_values(['성별', '기말고사'], ascending = [True, False])
# Out:
#       학번 분반 성별  중간고사  기말고사
# 17  2218  B  남    85   100
# 20  2221  A  남    91    98
# 16  2217  B  남    82    95
# 13  2214  A  남    76    93
# 18  2219  B  남    79    89
# 10  2211  B  남    88    85
# 19  2220  A  남    80    85
# 11  2212  B  남    85    82
# 14  2215  A  남    89    79
# 15  2216  A  남    32    57
# 12  2213  A  남    58    50
# 8   2209  B  여   100    98
# 7   2208  A  여    91    96
# 1   2202  A  여    82    91
# 4   2205  B  여    90    88
# 5   2206  B  여    84    82
# 3   2204  B  여    79    81
# 0   2201  B  여    82    79
# 6   2207  A  여    85    79
# 9   2210  B  여    72    70
# 2   2203  A  여    93    27

# %%
score1['학번'].count()
# Out:
# 21

# %%
score1[['중간고사', '기말고사']].mean()
# Out:
# 중간고사    81.095238
# 기말고사    81.142857
# dtype: float64

# %%
score1.groupby('분반')[['기말고사']].mean()
# Out:
#          기말고사
# 분반
# A   75.500000
# B   86.272727

# %%
score1.groupby(['분반', '성별'])[['중간고사', '기말고사']].mean()
# Out:
#         중간고사   기말고사
# 분반 성별
# A  남   71.00  77.00
#    여   87.75  73.25
# B  남   83.80  90.20
#    여   84.50  83.00

# %%
score2 = pd.read_csv('출석프로젝트성적.csv', encoding = 'EUC_KR')
score2.head()
# Out:
#      학번  출석  프로젝트
# 0  2201  74    65
# 1  2202  77    73
# 2  2203  76    75
# 3  2204  85    85
# 4  2205  95    95

# %%
test1 = pd.read_csv('test.csv', encoding = 'EUC_KR')
test1
# Out:
#      학번  출석  프로젝트
# 0  2323   0     0
# 1  2201  74    65

# %%
MgScore = pd.merge(score1, score2)
MgScore.head()
# Out:
#      학번 분반 성별  중간고사  기말고사  출석  프로젝트
# 0  2201  B  여    82    79  74    65
# 1  2202  A  여    82    91  77    73
# 2  2203  A  여    93    27  76    75
# 3  2204  B  여    79    81  85    85
# 4  2205  B  여    90    88  95    95

# %%
MgScore = pd.merge(score1, score2, on = '학번')
MgScore.head()
# Out:
#      학번 분반 성별  중간고사  기말고사  출석  프로젝트
# 0  2201  B  여    82    79  74    65
# 1  2202  A  여    82    91  77    73
# 2  2203  A  여    93    27  76    75
# 3  2204  B  여    79    81  85    85
# 4  2205  B  여    90    88  95    95

# %%
MgScore = pd.merge(score1, score2, on = '학번', how = 'outer')
MgScore.tail()
# Out:
#       학번 분반 성별  중간고사  기말고사  출석  프로젝트
# 16  2217  B  남    82    95  81    79
# 17  2218  B  남    85   100  88    87
# 18  2219  B  남    79    89  82    80
# 19  2220  A  남    80    85  79    76
# 20  2221  A  남    91    98  96   100

# %%
test1 = pd.read_csv('test.csv', encoding = 'EUC_KR')
test1
# Out:
#      학번  출석  프로젝트
# 0  2323   0     0
# 1  2201  74    65

# %%
test2 = pd.read_csv('test2.csv', encoding = 'EUC_KR')
test2
# Out:
#      학번  출석  프로젝트
# 0  2324  80    95
# 1  2325  50    65

# %%
test = pd.concat([test1, test2])
test
# Out:
#      학번  출석  프로젝트
# 0  2323   0     0
# 1  2201  74    65
# 0  2324  80    95
# 1  2325  50    65
