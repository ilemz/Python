# %%
import seaborn as sns
import pandas as pd
import matplotlib

# %%
b_name = pd.read_excel('책 이름.xlsx')
b_name['상품명'].describe(include = 'all')
# Out:
# count     239
# unique    239
# top       pre
# freq        1
# Name: 상품명, dtype: object

# %%
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
data.shape
# Out:
# (891, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.describe(include = 'object')
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
data.describe(include = 'all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# count   891.000000      889    891  891        891  203          889   891
# unique         NaN        3      3    3          2    7            3     2
# top            NaN        S  Third  man       True    C  Southampton    no
# freq           NaN      644    491  537        537   59          644   549
# mean     32.204208      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# std      49.693429      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 25%       7.910400      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 50%      14.454200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 75%      31.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
#
#        alone
# count    891
# unique     2
# top     True
# freq     537
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %%
data = sns.load_dataset('titanic')
data['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
data['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
data['class'].value_counts(normalize = True)
# Out:
# Third     0.551066
# First     0.242424
# Second    0.206510
# Name: class, dtype: float64

# %%
data['class'].value_counts(sort = False)
# Out:
# First     216
# Second    184
# Third     491
# Name: class, dtype: int64

# %%
data['class'].value_counts(normalize = True, sort = False)
# Out:
# First     0.242424
# Second    0.206510
# Third     0.551066
# Name: class, dtype: float64

# %%
data = pd.read_excel('연도별출생인구.xlsx')
data.head()
# Out:
#      연도    출생아수  천명당출생률
# 0  1951  728175    37.7
# 1  1952  775630    39.6
# 2  1953  830330    41.6
# 3  1954  892236    43.4
# 4  1955  961055    45.4

# %%
data.head(10)
# Out:
#      연도     출생아수  천명당출생률
# 0  1951   728175    37.7
# 1  1952   775630    39.6
# 2  1953   830330    41.6
# 3  1954   892236    43.4
# 4  1955   961055    45.4
# 5  1956   999005    45.2
# 6  1957  1016573    44.8
# 7  1958  1046011    44.5
# 8  1959  1074876    44.2
# 9  1960  1099294    44.0

# %%
data.tail()
# Out:
#       연도    출생아수  천명당출생률
# 63  2014  435435     8.6
# 64  2015  438420     8.6
# 65  2016  406243     7.9
# 66  2017  357771     7.0
# 67  2018  326900     6.4

# %%
data.tail(10)
# Out:
#       연도    출생아수  천명당출생률
# 58  2009  444849     9.0
# 59  2010  470171     9.4
# 60  2011  471265     9.4
# 61  2012  484550     9.6
# 62  2013  436455     8.6
# 63  2014  435435     8.6
# 64  2015  438420     8.6
# 65  2016  406243     7.9
# 66  2017  357771     7.0
# 67  2018  326900     6.4

# %%
data[0:3]
# Out:
#      연도    출생아수  천명당출생률
# 0  1951  728175    37.7
# 1  1952  775630    39.6
# 2  1953  830330    41.6

# %%
data[:3]
# Out:
#      연도    출생아수  천명당출생률
# 0  1951  728175    37.7
# 1  1952  775630    39.6
# 2  1953  830330    41.6

# %%
data[20:25]
# Out:
#       연도     출생아수  천명당출생률
# 20  1971  1024773    31.2
# 21  1972   952780    28.4
# 22  1973   965521    28.3
# 23  1974   922823    26.6
# 24  1975   874030    24.8

# %%
data[65:]
# Out:
#       연도    출생아수  천명당출생률
# 65  2016  406243     7.9
# 66  2017  357771     7.0
# 67  2018  326900     6.4

# %%
data['연도']
# Out:
# 0     1951
# 1     1952
# 2     1953
# 3     1954
# 4     1955
#       ...
# 63    2014
# 64    2015
# 65    2016
# 66    2017
# 67    2018
# Name: 연도, Length: 68, dtype: int64

# %%
data['출생아수']
# Out:
# 0     728175
# 1     775630
# 2     830330
# 3     892236
# 4     961055
#        ...
# 63    435435
# 64    438420
# 65    406243
# 66    357771
# 67    326900
# Name: 출생아수, Length: 68, dtype: int64

# %%
data[['연도', '천명당출생률']]
# Out:
#       연도  천명당출생률
# 0   1951    37.7
# 1   1952    39.6
# 2   1953    41.6
# 3   1954    43.4
# 4   1955    45.4
# ..   ...     ...
# 63  2014     8.6
# 64  2015     8.6
# 65  2016     7.9
# 66  2017     7.0
# 67  2018     6.4
#
# [68 rows x 2 columns]

# %%
data['출생아수'][3]
# Out:
# 892236

# %%
data['연도'][10:15]
# Out:
# 10    1961
# 11    1962
# 12    1963
# 13    1964
# 14    1965
# Name: 연도, dtype: int64

# %%
data[['연도', '천명당출생률']][20:25]
# Out:
#       연도  천명당출생률
# 20  1971    31.2
# 21  1972    28.4
# 22  1973    28.3
# 23  1974    26.6
# 24  1975    24.8

# %%
last = data[65:]
last
# Out:
#       연도    출생아수  천명당출생률
# 65  2016  406243     7.9
# 66  2017  357771     7.0
# 67  2018  326900     6.4

# %%
subData = data[['연도', '천명당출생률']][20:25]
subData
# Out:
#       연도  천명당출생률
# 20  1971    31.2
# 21  1972    28.4
# 22  1973    28.3
# 23  1974    26.6
# 24  1975    24.8

# %%
aptData = pd.read_excel('상도동 아파트 실거래가.xlsx', header = [16])

# %%
aptData.head()
# Out:
#    서울특별시 동작구 상도동  903  0903  0000  e편한세상상도노빌리티  108.9843  202306   9  \
# 0  서울특별시 동작구 상도동  903   903     0  e편한세상상도노빌리티   84.9704  202306  10
# 1  서울특별시 동작구 상도동  903   903     0  e편한세상상도노빌리티   84.9704  202306  13
# 2  서울특별시 동작구 상도동  903   903     0  e편한세상상도노빌리티   84.9704  202306  14
# 3  서울특별시 동작구 상도동  903   903     0  e편한세상상도노빌리티   84.9704  202306  21
# 4  서울특별시 동작구 상도동  903   903     0  e편한세상상도노빌리티   84.9704  202306  30
#
#           167,000  14  2018  만양로 6  Unnamed: 12
# 0         138,000  21  2018  만양로 6          NaN
# 1         140,000   6  2018  만양로 6          NaN
# 2         142,500  12  2018  만양로 6          NaN
# 3         143,000   1  2018  만양로 6          NaN
# 4         138,500   4  2018  만양로 6          NaN

# %%
aptData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   서울특별시 동작구 상도동   195 non-null    object
#  1   903             195 non-null    object
#  2   0903            195 non-null    int64
#  3   0000            195 non-null    int64
#  4   e편한세상상도노빌리티     195 non-null    object
#  5   108.9843        195 non-null    float64
#  6   202306          195 non-null    int64
#  7   9               195 non-null    int64
#  8          167,000  195 non-null    object
#  9   14              195 non-null    int64
#  10  2018            195 non-null    int64
#  11  만양로 6           195 non-null    object
#  12  Unnamed: 12     0 non-null      float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 19.9+ KB

# %%
data = aptData.drop(index = [0], axis = 0)
data.head(20)
# Out:
#     서울특별시 동작구 상도동  903  0903  0000  e편한세상상도노빌리티  108.9843  202306   9  \
# 1   서울특별시 동작구 상도동  903   903     0  e편한세상상도노빌리티   84.9704  202306  13
# 2   서울특별시 동작구 상도동  903   903     0  e편한세상상도노빌리티   84.9704  202306  14
# 3   서울특별시 동작구 상도동  903   903     0  e편한세상상도노빌리티   84.9704  202306  21
# 4   서울특별시 동작구 상도동  903   903     0  e편한세상상도노빌리티   84.9704  202306  30
# 5   서울특별시 동작구 상도동  414   414     0           건영   32.8000  202209  30
# 6   서울특별시 동작구 상도동  414   414     0           건영  114.9600  202306  28
# 7   서울특별시 동작구 상도동  445   445     0        경향렉스빌  114.6534  202305  16
# 8   서울특별시 동작구 상도동  411   411     0        대림아파트   84.8900  202208  23
# 9   서울특별시 동작구 상도동  411   411     0        대림아파트   66.5900  202210   4
# 10  서울특별시 동작구 상도동  411   411     0        대림아파트   84.8900  202303  19
# 11  서울특별시 동작구 상도동  411   411     0        대림아파트   84.8900  202303  23
# 12  서울특별시 동작구 상도동  411   411     0        대림아파트   66.5900  202303  28
# 13  서울특별시 동작구 상도동  411   411     0        대림아파트   84.8900  202306  15
# 14  서울특별시 동작구 상도동  528   528     0       동원베네스트   84.9590  202210  29
# 15  서울특별시 동작구 상도동  528   528     0       동원베네스트   84.9580  202306  24
# 16  서울특별시 동작구 상도동  535   535     0   두산위브트레지움2차   84.8640  202211  21
# 17  서울특별시 동작구 상도동  535   535     0   두산위브트레지움2차   84.8032  202302   1
# 18  서울특별시 동작구 상도동  535   535     0   두산위브트레지움2차   84.8624  202303  23
# 19  서울특별시 동작구 상도동  535   535     0   두산위브트레지움2차   84.8624  202304  14
# 20  서울특별시 동작구 상도동  535   535     0   두산위브트레지움2차   84.9736  202304  18
#
#            167,000  14  2018      만양로 6  Unnamed: 12
# 1          140,000   6  2018      만양로 6          NaN
# 2          142,500  12  2018      만양로 6          NaN
# 3          143,000   1  2018      만양로 6          NaN
# 4          138,500   4  2018      만양로 6          NaN
# 5           57,000   7  1997     만양로 26          NaN
# 6          101,500   8  1997     만양로 26          NaN
# 7           77,000   6  2002   양녕로23길 9          NaN
# 8           87,000  11  1995  상도로60길 20          NaN
# 9           75,000  10  1995  상도로60길 20          NaN
# 10          70,000   4  1995  상도로60길 20          NaN
# 11          65,000   1  1995  상도로60길 20          NaN
# 12          65,000   7  1995  상도로60길 20          NaN
# 13          69,000   1  1995  상도로60길 20          NaN
# 14          93,000   5  2008  상도로34길 42          NaN
# 15          94,000   3  2008  상도로34길 42          NaN
# 16         120,000  21  2016  상도로30길 40          NaN
# 17         126,000  10  2016  상도로30길 40          NaN
# 18         123,500  11  2016  상도로30길 40          NaN
# 19         129,000  12  2016  상도로30길 40          NaN
# 20         127,000  10  2016  상도로30길 40          NaN

# %%
aptData.drop(aptData.index[0:17], axis = 0, inplace = True)
aptData.head()
# Out:
#     서울특별시 동작구 상도동  903  0903  0000 e편한세상상도노빌리티  108.9843  202306   9  \
# 17  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.8032  202302   1
# 18  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.8624  202303  23
# 19  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.8624  202304  14
# 20  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.9736  202304  18
# 21  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.8640  202306   2
#
#            167,000  14  2018      만양로 6  Unnamed: 12
# 17         126,000  10  2016  상도로30길 40          NaN
# 18         123,500  11  2016  상도로30길 40          NaN
# 19         129,000  12  2016  상도로30길 40          NaN
# 20         127,000  10  2016  상도로30길 40          NaN
# 21         128,000  23  2016  상도로30길 40          NaN

# %%
aptData.reset_index()
# Out:
#      index  서울특별시 동작구 상도동  903  0903  0000     e편한세상상도노빌리티  108.9843  202306  \
# 0        0  서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.8032  202302
# 1        1  서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.8624  202303
# 2        2  서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.8624  202304
# 3        3  서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.9736  202304
# 4        4  서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.8640  202306
# ..     ...            ...  ...   ...   ...             ...       ...     ...
# 173    173  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지   84.9510  202303
# 174    174  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지   84.9510  202303
# 175    175  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지   84.9510  202304
# 176    176  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지   84.8840  202306
# 177    177  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지  120.9360  202306
#
#       9         167,000  14  2018      만양로 6  Unnamed: 12
# 0     1         126,000  10  2016  상도로30길 40          NaN
# 1    23         123,500  11  2016  상도로30길 40          NaN
# 2    14         129,000  12  2016  상도로30길 40          NaN
# 3    18         127,000  10  2016  상도로30길 40          NaN
# 4     2         128,000  23  2016  상도로30길 40          NaN
# ..   ..             ...  ..   ...        ...          ...
# 173  12         109,000   4  2013  상도로 346-2          NaN
# 174  23         113,000   5  2013  상도로 346-2          NaN
# 175   1         120,000   9  2013  상도로 346-2          NaN
# 176  16         125,500   6  2013  상도로 346-2          NaN
# 177  24         160,000  10  2013  상도로 346-2          NaN
#
# [178 rows x 14 columns]

# %%
aptData.reset_index(drop = True, inplace = True)
aptData.head()
# Out:
#    서울특별시 동작구 상도동  903  0903  0000 e편한세상상도노빌리티  108.9843  202306   9  \
# 0  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.8032  202302   1
# 1  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.8624  202303  23
# 2  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.8624  202304  14
# 3  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.9736  202304  18
# 4  서울특별시 동작구 상도동  535   535     0  두산위브트레지움2차   84.8640  202306   2
#
#           167,000  14  2018      만양로 6  Unnamed: 12
# 0         126,000  10  2016  상도로30길 40          NaN
# 1         123,500  11  2016  상도로30길 40          NaN
# 2         129,000  12  2016  상도로30길 40          NaN
# 3         127,000  10  2016  상도로30길 40          NaN
# 4         128,000  23  2016  상도로30길 40          NaN

# %%
data = aptData.drop(aptData.columns[1:4], axis = 1)
data.head()
# Out:
#    서울특별시 동작구 상도동 e편한세상상도노빌리티  108.9843  202306   9         167,000  14  2018  \
# 0  서울특별시 동작구 상도동  두산위브트레지움2차   84.8032  202302   1         126,000  10  2016
# 1  서울특별시 동작구 상도동  두산위브트레지움2차   84.8624  202303  23         123,500  11  2016
# 2  서울특별시 동작구 상도동  두산위브트레지움2차   84.8624  202304  14         129,000  12  2016
# 3  서울특별시 동작구 상도동  두산위브트레지움2차   84.9736  202304  18         127,000  10  2016
# 4  서울특별시 동작구 상도동  두산위브트레지움2차   84.8640  202306   2         128,000  23  2016
#
#        만양로 6  Unnamed: 12
# 0  상도로30길 40          NaN
# 1  상도로30길 40          NaN
# 2  상도로30길 40          NaN
# 3  상도로30길 40          NaN
# 4  상도로30길 40          NaN

# %%
aptData.rename(columns = {'전용면적' : '전용면적', '거래금액' : '거래금액'}, inplace = True)
aptData
# Out:
#      서울특별시 동작구 상도동  903  0903  0000     e편한세상상도노빌리티  108.9843  202306   9  \
# 0    서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.8032  202302   1
# 1    서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.8624  202303  23
# 2    서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.8624  202304  14
# 3    서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.9736  202304  18
# 4    서울특별시 동작구 상도동  535   535     0      두산위브트레지움2차   84.8640  202306   2
# ..             ...  ...   ...   ...             ...       ...     ...  ..
# 173  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지   84.9510  202303  12
# 174  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지   84.9510  202303  23
# 175  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지   84.9510  202304   1
# 176  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지   84.8840  202306  16
# 177  서울특별시 동작구 상도동  533   533     0  힐스테이트 상도 프레스티지  120.9360  202306  24
#
#             167,000  14  2018      만양로 6  Unnamed: 12
# 0           126,000  10  2016  상도로30길 40          NaN
# 1           123,500  11  2016  상도로30길 40          NaN
# 2           129,000  12  2016  상도로30길 40          NaN
# 3           127,000  10  2016  상도로30길 40          NaN
# 4           128,000  23  2016  상도로30길 40          NaN
# ..              ...  ..   ...        ...          ...
# 173         109,000   4  2013  상도로 346-2          NaN
# 174         113,000   5  2013  상도로 346-2          NaN
# 175         120,000   9  2013  상도로 346-2          NaN
# 176         125,500   6  2013  상도로 346-2          NaN
# 177         160,000  10  2013  상도로 346-2          NaN
#
# [178 rows x 13 columns]
